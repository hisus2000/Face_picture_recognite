# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
cd '/content/gdrive/MyDrive/project/CNN'
# Out:
# /content/gdrive/MyDrive/project/CNN

# %%
ls
# Out:
# model_checkpoint_new.h5  PulRename.exe       test_set/
# my_model_CNN_new.h5      single_prediction/  training_test/

# %%
from tensorflow.keras.models import load_model
classifier = load_model('my_model_CNN_new.h5')
print("Done")
# Out:
# Done

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

# %%
test_image = image.load_img('/content/gdrive/MyDrive/project/CNN/single_prediction/hien.jpg',
                            target_size = (256,256))

test_image = image.img_to_array(test_image)
# print(test_image.shape)
test_image = test_image/255
test_image =  np.expand_dims(test_image, axis =0)
# print(test_image.shape)
result = classifier.predict(test_image)
# print(result)

#training_set.class_indices
if round(result[0][0]) ==1:
    prediction = "bao_han"
elif round(result[0][1]) ==1:
    prediction = 'danh'
elif round(result[0][2]) ==1:
    prediction = 'diep'
elif round(result[0][3]) ==1:
    prediction = 'hien'
elif round(result[0][4]) ==1:
    prediction = 'hong'
else:
  prediction = 'tuan'
print(prediction)

# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img =mpimg.imread('/content/gdrive/MyDrive/project/CNN/single_prediction/hien.jpg')
imgplot = plt.imshow(img)
plt.show()
# Out:
# hien
# Populating the interactive namespace from numpy and matplotlib

# %%
test_image = image.load_img('/content/gdrive/MyDrive/project/CNN/single_prediction/hong.jpg',
                            target_size = (256,256))
test_image = image.img_to_array(test_image)
test_image = test_image/255
test_image =  np.expand_dims(test_image, axis =0)
result = classifier.predict(test_image)


if round(result[0][0]) ==1:
    prediction = "bao_han"
elif round(result[0][1]) ==1:
    prediction = 'danh'
elif round(result[0][2]) ==1:
    prediction = 'diep'
elif round(result[0][3]) ==1:
    prediction = 'hien'
elif round(result[0][4]) ==1:
    prediction = 'hong'
else:
  prediction = 'tuan'
print(prediction)

# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img =mpimg.imread('/content/gdrive/MyDrive/project/CNN/single_prediction/hong.jpg')
imgplot = plt.imshow(img)
plt.show()
# Out:
# hong
# Populating the interactive namespace from numpy and matplotlib

# %%
test_image = image.load_img('/content/gdrive/MyDrive/project/CNN/single_prediction/danh.jpg',
                            target_size = (256,256))
test_image = image.img_to_array(test_image)
test_image = test_image/255
test_image =  np.expand_dims(test_image, axis =0)
result = classifier.predict(test_image)


if round(result[0][0]) ==1:
    prediction = "bao_han"
elif round(result[0][1]) ==1:
    prediction = 'danh'
elif round(result[0][2]) ==1:
    prediction = 'diep'
elif round(result[0][3]) ==1:
    prediction = 'hien'
elif round(result[0][4]) ==1:
    prediction = 'hong'
else:
  prediction = 'tuan'
print(prediction)

# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img =mpimg.imread('/content/gdrive/MyDrive/project/CNN/single_prediction/danh.jpg')
imgplot = plt.imshow(img)
plt.show()
# Out:
# danh
# Populating the interactive namespace from numpy and matplotlib

# %%
test_image = image.load_img('/content/gdrive/MyDrive/project/CNN/single_prediction/diep.jpg',
                            target_size = (256,256))
test_image = image.img_to_array(test_image)
test_image = test_image/255
test_image =  np.expand_dims(test_image, axis =0)
result = classifier.predict(test_image)


if round(result[0][0]) ==1:
    prediction = "bao_han"
elif round(result[0][1]) ==1:
    prediction = 'danh'
elif round(result[0][2]) ==1:
    prediction = 'diep'
elif round(result[0][3]) ==1:
    prediction = 'hien'
elif round(result[0][4]) ==1:
    prediction = 'hong'
else:
  prediction = 'tuan'
print(prediction)

# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img =mpimg.imread('/content/gdrive/MyDrive/project/CNN/single_prediction/diep.jpg')
imgplot = plt.imshow(img)
plt.show()
# Out:
# diep
# Populating the interactive namespace from numpy and matplotlib

# %%
test_image = image.load_img('/content/gdrive/MyDrive/project/CNN/single_prediction/tuan.jpg',
                            target_size = (256,256))
test_image = image.img_to_array(test_image)
test_image = test_image/255
test_image =  np.expand_dims(test_image, axis =0)
result = classifier.predict(test_image)


if round(result[0][0]) ==1:
    prediction = "bao_han"
elif round(result[0][1]) ==1:
    prediction = 'danh'
elif round(result[0][2]) ==1:
    prediction = 'diep'
elif round(result[0][3]) ==1:
    prediction = 'hien'
elif round(result[0][4]) ==1:
    prediction = 'hong'
else:
  prediction = 'tuan'
print(prediction)

# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img =mpimg.imread('/content/gdrive/MyDrive/project/CNN/single_prediction/tuan.jpg')
imgplot = plt.imshow(img)
plt.show()
# Out:
# tuan
# Populating the interactive namespace from numpy and matplotlib

# %%
test_image = image.load_img('/content/gdrive/MyDrive/project/CNN/single_prediction/han.jpg',
                            target_size = (256,256))
test_image = image.img_to_array(test_image)
test_image = test_image/255
test_image =  np.expand_dims(test_image, axis =0)
result = classifier.predict(test_image)


if round(result[0][0]) ==1:
    prediction = "bao_han"
elif round(result[0][1]) ==1:
    prediction = 'danh'
elif round(result[0][2]) ==1:
    prediction = 'diep'
elif round(result[0][3]) ==1:
    prediction = 'hien'
elif round(result[0][4]) ==1:
    prediction = 'hong'
else:
  prediction = 'tuan'
print(prediction)

# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img =mpimg.imread('/content/gdrive/MyDrive/project/CNN/single_prediction/han.jpg')
imgplot = plt.imshow(img)
plt.show()
# Out:
# bao_han
# Populating the interactive namespace from numpy and matplotlib
